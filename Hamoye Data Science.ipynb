# %%
A = [1,2,3,4,5,6]
B = [13, 21, 34]

A_B = list.__add__(A, B)
print(A_B)
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %%
import pandas as pd
fuel_data = pd.read_csv('fuel_ferc1.csv',error_bad_lines=False)
fuel_data.describe(include='all')
# Out:
#                       record_id  utility_id_ferc1   report_year  \
# count                     29523      29523.000000  29523.000000
# unique                    29523               NaN           NaN
# top     f1_fuel_1995_12_135_1_4               NaN           NaN
# freq                          1               NaN           NaN
# mean                        NaN        118.601836   2005.806050
# std                         NaN         74.178353      7.025483
# min                         NaN          1.000000   1994.000000
# 25%                         NaN         55.000000   2000.000000
# 50%                         NaN        122.000000   2006.000000
# 75%                         NaN        176.000000   2012.000000
# max                         NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
#Question
#Which feature has missing values and what is the total number of missing value and percentage of the missing rows as a factor of the total number of rows in three decimal places?

#(Enter answer in the format: Feature: xxx, Total: xxx, Percent: xxx)


#Answer:   
#Feature: fuel_unit, Total: 180, Percent: 6.111

fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
#Question: Which of the features has the second and third lowest correlation with the Fuel Cost Per Unit Burned?

#Answer
#From the table, the answer is Fuel_cost_per_unit_delivered and utility_id_ferc1
fuel_data.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  \
# utility_id_ferc1                        -0.066946
# report_year                             -0.110853
# fuel_qty_burned                         -0.080946
# fuel_mmbtu_per_unit                      1.000000
# fuel_cost_per_unit_delivered            -0.009039
# fuel_cost_per_mmbtu                     -0.005884
#
#                               fuel_cost_per_unit_delivered  \
# ...

# %%
import numpy as np
from scipy.stats import  skew
from scipy.stats import  kurtosis
import matplotlib.pyplot as plt
import statistics as stats


# The skewness of fuel_qty_burned 
round(fuel_data['fuel_qty_burned'].skew(axis = 0, skipna = True),2)
# Out:
# 15.85

# %%
# The kurtosis of fuel_qty_burned

round(fuel_data['fuel_qty_burned'].kurtosis(axis = 0, skipna = True),2)
# Out:
# 651.37
